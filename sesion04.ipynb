# %%
print ("II***I**I  ")
print ("I***I****I")
print ("I***I****I")
print (" I I I I I" )
print ("  IIII")
print ("   II")
print ("   II")
print ("   II")
# Out:
# II***I**I
# I***I****I
# I***I****I
#  I I I I I
#   IIII
#    II
#    II
#    II

# %% [markdown]
# # Sesión 04
# - Mi primer notebook
# - Imprimir árbol
# - Crear Markdown
# - Subir a mi repositorio de GitHub
